# %% [markdown]
# <a href="https://colab.research.google.com/github/Ernesto16/AI-Saturdays/blob/master/AI_Saturdays_(Web_scrapping).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Web Scrapping

# %%
pip install requests beautifulsoup4

# %%
import requests

# Sending a HTTP GET request
url = 'https://fantasy.premierleague.com/'
response = requests.get(url)


# Checking the response status code
print('Response Status Code: ', response.status_code)

# Print the first 200 characters of the response content
print('Response Content:')
print(response.text[:200])
# Out:
# Response Status Code:  200
# Response Content:
# <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#         <!-- OneTrust Cookies Consent Notice start for premierleague.com -->
#         <script
#             charset="UTF-8"
#             data-domain-script="cd

# %%
from bs4 import BeautifulSoup

# Parsing the HTML content
soup = BeautifulSoup(response.content, "html.parser")

# Print the prettified HTML
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- OneTrust Cookies Consent Notice start for premierleague.com -->
#   <script charset="UTF-8" data-domain-script="cdf436a9-4615-4772-a4b4-7660a91cc3a2" src="https://cdn-ukwest.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://cc-embed.adobe.com/sdk/v4/CCEverywhere.js">
#   </script>
#   <script async="" src="https://assets.adobedtm.com/e7ad550d4f82/693c01019a2b/launch-a4f579b5dcc4.min.js">
#   </script>
#   <script id="ism-environment-paths">
#    if (!window.PULSE) {
#                 window.PULSE = {};
#             }
#             window.PULSE.envPaths = {
#                 label: "production",
#                 domain: [
#                     "web25.premierleague.pulselive.com",
#                     "www.premierleague.com",
#                 ],
#                 cdn: "//www.premierleague.com/resources/v1.26.16/",
#                 api: "//api.premierleague.com",
# ...

# %%
# Finding <h1> and <h2> tags and extracting its text
header = soup.find('h1')
print('Header_1:', header)

header = soup.find('h2')
print('Header_2:', header)
# Out:
# Header_1: None
# Header_2: None

# %%
# Find all <a> tags and extract their href attributes
links = soup.find_all("a")
for link in links:
    print("Link:", link.get("href"))
# Out:
# Link: https://www.premierleague.com/en/
# Link: https://shop.premierleague.com/gb/en/home/
# Link: https://www.premierleague.com/en/about
# Link: https://www.premierleague.com/en/footballandcommunity
# Link: https://www.premierleague.com/en/events
# Link: https://www.premierleague.com/en/other-competitions
# Link: https://www.premierleague.com/en/media/statements
# Link: https://www.premierleague.com/en/events/summerseries
# Link: https://www.premierleague.com/en
# Link: https://www.premierleague.com/en/matches
# Link: https://www.premierleague.com/en/tables
# Link: https://www.premierleague.com/en/stats
# Link: https://www.premierleague.com/en/fantasy
# Link: https://draft.premierleague.com/
# Link: https://fplchallenge.premierleague.com/home
# Link: https://www.premierleague.com/en/news
# Link: https://www.premierleague.com/en/players
# Link: https://www.premierleague.com/en/clubs
# Link: https://www.premierleague.com/en/video
# Link: /en
# Link: https://www.premierleague.com/en/
# ...

# %%
# Example of navigating through pagination
base_url = "https://fantasy.premierleague.com//page={}"

for page_num in range(1, 6):
    page_url = base_url.format(page_num)
    page_response = requests.get(page_url)
    # Parse and extract data from the page_response

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")

        # Extracting all headings
        headings = soup.find_all("h2")
        print(f"\n--- Page {page_num} ---")
        for heading in headings:
            print(heading.get_text(strip=True))
    else:
        print(f"Failed to fetch page {page_num}, status code: {response.status_code}")
# Out:
# --- Page 1 ---
#
# --- Page 2 ---
#
# --- Page 3 ---
#
# --- Page 4 ---
#
# --- Page 5 ---
